# %% [markdown]
# [jupyter notebook](read_write.ipynb)
# # read and write

# %% [markdown]
# ### Read from csv file

# %%
import pandas as pd

df = pd.read_csv( 'data.csv' )

# %% [markdown]
# ### Write to csv file

# %%
import pandas as pd

df = pd.DataFrame( { 'A': [ 'a', 'a', 'b', 'a', 'b', 'b', 'a', 'b'],
                     'B': [  1 ,  4 ,  2 ,  5 ,  5 ,  6 ,  3 ,  1 ],
                     'C': [  9 ,  7 ,  3 ,  5 ,  1 ,  4 ,  7 ,  2 ] } )

dfSource.to_csv( 'data.csv' )

# %% [markdown]
# ### Read from Excel file

# %%
import pandas as pd

df = pd.read_excel( 'data.xlsx' )

# %% [markdown]
# ### Write to Excel file

# %%
import pandas as pd

writer = pd.ExcelWriter( 'data.xlsx' )
df.to_excel( writer, 'Sheet1' )
writer.save()
